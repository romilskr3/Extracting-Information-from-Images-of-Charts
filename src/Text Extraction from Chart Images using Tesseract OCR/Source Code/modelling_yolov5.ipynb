# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/text_extraction_dataset/yolov5
# !python train.py --epochs 10 --data text_extraction_dataset.yaml --weights yolov5s.pt --cache
# Out:
# /content/drive/MyDrive/text_extraction_dataset/yolov5
# train: weights=yolov5s.pt, cfg=, data=text_extraction_dataset.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=10, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (Docker image), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 v6.1-325-g3e85863 Python-3.7.13 torch-1.12.0+cu113 CPU
#
# ...

# %%
# %cd /content/drive/MyDrive/text_extraction_dataset/yolov5
# !python val.py --data text_extraction_dataset.yaml --weights runs/train/exp6/weights/best.pt
# Out:
# /content/drive/MyDrive/text_extraction_dataset/yolov5
# val: data=/content/drive/MyDrive/text_extraction_dataset/yolov5/data/text_extraction_dataset.yaml, weights=['runs/train/exp6/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.75, iou_thres=0.8, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# WARNING: confidence threshold 0.75 > 0.001 produces invalid results ⚠️
# YOLOv5 🚀 v6.1-325-g3e85863 Python-3.7.13 torch-1.12.0+cu113 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7020913 parameters, 0 gradients
# val: Scanning '/content/drive/MyDrive/text_extraction_dataset/yolov5/../dataset/labels/val.cache' images and labels... 389 found, 0 missing, 0 empty, 1 corrupt: 100% 389/389 [00:00<?, ?it/s]
# ...

# %%
# %cd /content/drive/MyDrive/text_extraction_dataset/yolov5/
# !python detect.py --weights runs/train/exp6/weights/best.pt --img 416 --conf 0.75 --source test
# Out:
# /content/drive/MyDrive/text_extraction_dataset/yolov5
# detect: weights=['runs/train/exp6/weights/best.pt'], source=test, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.75, iou_thres=0.8, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=2, hide_labels=False, hide_conf=True, half=False, dnn=False
# YOLOv5 🚀 v6.1-325-g3e85863 Python-3.7.13 torch-1.12.0+cu113 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7020913 parameters, 0 gradients
# image 1/379 /content/drive/MyDrive/text_extraction_dataset/yolov5/test/10147.png: 288x416 1 x_axis_label, 2 y_axis_labels, 2 legend_elementss, Done. (0.256s)
# image 2/379 /content/drive/MyDrive/text_extraction_dataset/yolov5/test/10148.png: 288x416 1 x_axis_label, 1 y_axis_label, 4 legend_elementss, Done. (0.130s)
# ...
